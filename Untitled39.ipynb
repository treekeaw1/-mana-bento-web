2003/08/16,354771,00
2003/08/01,766098,91
2003/07/16,679545,75
2003/07/01,461414,91
2003/06/16,389872,29
2003/06/01,766066,36
2003/05/16,552784,20
2003/05/02,135603,12
2003/04/16,892525,21
2003/04/01,933164,86
2003/03/16,653062,64
2003/03/01,441022,42
2003/02/17,455578,61
2003/02/01,456370,94
2003/01/16,977085,06
2002/12/30,895196,95
2002/12/16,019682,67
2002/12/01,968422,37
2002/11/16,915344,55
2002/11/01,505498,25
2002/10/16,428641,51
2002/10/01,802505,72
2002/09/16,156050,85
2002/09/01,994200,51
2002/08/16,120108,57
2002/08/01,493438,88
2002/07/16,340264,69
2002/07/01,481447,24
2002/06/16,073261,07
2002/06/01,161149,02
2002/05/16,598714,76
2002/05/02,590664,56
2002/04/16,522630,37
2002/04/01,990543,57
2002/03/16,659152,04
2002/03/01,805590,55
2002/02/16,330853,92
2002/02/01,633270,40
2002/01/16,709670,14
"""

def parse_lottery_data(raw_data):
    """
    Parse raw lottery data into lists of 3-digit and 2-digit numbers.
    """
    lines = raw_data.strip().split('\n')
    prize1_3digits = []
    last2_digits = []

    for line in lines:
        parts = line.split(',')
        if len(parts) == 3:
            # Extract last 3 digits of prize 1
            prize1_full = parts[1].strip()
            prize1_3digits.append(prize1_full[-3:])

            # Extract last 2 digits
            last2_digits.append(parts[2].strip())

    return prize1_3digits, last2_digits

def analyze_numbers(numbers, digits, num_recent_draws=20):
    """
    Analyze frequency of numbers, identifying hot, cold, and recent numbers.
    Args:
        numbers (list): List of numbers (e.g., ['91', '06', '20'] or ['246', '392', '352']).
        digits (int): Number of digits (2 for 2-digit, 3 for 3-digit).
        num_recent_draws (int): Number of recent draws to consider for "recent hot" numbers.
    Returns:
        dict: Analysis results including frequencies, hot, cold, and recent hot numbers.
    """
    all_possible_numbers = [str(i).zfill(digits) for i in range(10**digits)]

    # Calculate overall frequencies
    overall_frequencies = collections.Counter(numbers)

    # Calculate recent frequencies
    recent_numbers = numbers[:num_recent_draws] # Take the most recent draws
    recent_frequencies = collections.Counter(recent_numbers)

    # Categorize numbers
    hot_numbers = [] # Top overall frequency
    cold_numbers = [] # Frequency of 1
    dead_numbers = [] # Frequency of 0
    recent_hot_numbers = [] # Top frequency in recent draws

    # Sort numbers by overall frequency (descending)
    sorted_overall = sorted(overall_frequencies.items(), key=lambda item: item[1], reverse=True)

    # Sort numbers by recent frequency (descending)
    sorted_recent = sorted(recent_frequencies.items(), key=lambda item: item[1], reverse=True)

    for num in all_possible_numbers:
        overall_freq = overall_frequencies[num]
        recent_freq = recent_frequencies[num]

        if overall_freq == 0:
            dead_numbers.append(num)
        elif overall_freq == 1:
            cold_numbers.append(num)
        # Hot numbers are taken from sorted_overall

    # Get top 10 overall hot numbers
    hot_numbers = [{'number': num, 'frequency': freq} for num, freq in sorted_overall if freq > 1][:10]

    # Get top 5 recent hot numbers (consider those not already in top overall hot numbers)
    # This helps identify "rebounding" or newly active numbers

    # Filter out dead numbers from recent_hot_numbers consideration
    temp_recent_hot = []
    for num, freq in sorted_recent:
        if num not in dead_numbers and freq > 0: # Ensure it's not a dead number overall
            temp_recent_hot.append({'number': num, 'frequency': freq})

    recent_hot_numbers = temp_recent_hot[:5] # Take top 5 from recent analysis

    # Identify "resting" numbers: High overall frequency, but low/zero recent frequency
    resting_numbers = []
    # Consider top 20 overall numbers, if their recent frequency is less than 2
    for num_freq in sorted_overall[:20]: # Look at top 20 overall
        num, overall_freq = num_freq
        if recent_frequencies[num] < 2 and overall_freq > 2: # High overall, low recent
            if num not in hot_numbers and num not in dead_numbers: # Not currently hot or dead
                resting_numbers.append({'number': num, 'overall_frequency': overall_freq, 'recent_frequency': recent_frequencies[num]})

    # Sort resting numbers by overall frequency for better relevance
    resting_numbers.sort(key=lambda x: x['overall_frequency'], reverse=True)


    return {
        'totalDraws': len(numbers),
        'possibleNumbers': len(all_possible_numbers),
        'overallFrequencies': overall_frequencies,
        'recentFrequencies': recent_frequencies,
        'hotNumbers': hot_numbers,
        'coldNumbers': cold_numbers,
        'deadNumbers': dead_numbers,
        'recentHotNumbers': recent_hot_numbers,
        'restingNumbers': resting_numbers,
        'sortedOverall': sorted_overall # Keep for broader selection
    }

def predict_4_sets(analysis_result, digits):
    """
    Predicts 4 sets of numbers based on analysis, emphasizing frequency and recent trends.
    """
    all_possible_numbers_set = set([str(i).zfill(digits) for i in range(10**digits)])

    # Excluded numbers (dead, cold)
    excluded = set(analysis_result['deadNumbers'] + analysis_result['coldNumbers'])

    # All eligible numbers (not dead or cold)
    eligible_overall = [num for num, freq in analysis_result['sortedOverall'] if num not in excluded]

    predictions = {}
    selected_numbers = set()

    # --- ชุดคาดการณ์ที่ 1 (เลขร้อนยอดนิยมจากทุกช่วง) ---
    # เลือกจากเลขร้อน overall ที่ยังไม่ถูกเลือก
    set1_candidates = [item['number'] for item in analysis_result['hotNumbers'] if item['number'] not in selected_numbers]
    predictions['ชุดคาดการณ์ที่ 1 (เลขร้อนยอดนิยมจากทุกช่วง)'] = set1_candidates[:4]
    selected_numbers.update(predictions['ชุดคาดการณ์ที่ 1 (เลขร้อนยอดนิยมจากทุกช่วง)'])

    # --- ชุดคาดการณ์ที่ 2 (เลขที่เพิ่งกลับมาฮิต / ร้อนในงวดล่าสุด) ---
    # เลือกจาก recent_hot_numbers ที่ยังไม่ถูกเลือก
    set2_candidates = [item['number'] for item in analysis_result['recentHotNumbers'] if item['number'] not in selected_numbers]
    predictions['ชุดคาดการณ์ที่ 2 (เลขร้อนในงวดล่าสุด)'] = set2_candidates[:4]
    selected_numbers.update(predictions['ชุดคาดการณ์ที่ 2 (เลขร้อนในงวดล่าสุด)'])

    # --- ชุดคาดการณ์ที่ 3 (เลขที่พักตัวและมีโอกาสกลับมา) ---
    # เลือกจาก resting_numbers ที่ยังไม่ถูกเลือก
    set3_candidates = [item['number'] for item in analysis_result['restingNumbers'] if item['number'] not in selected_numbers]
    predictions['ชุดคาดการณ์ที่ 3 (เลขที่พักตัว มีโอกาสกลับมา)'] = set3_candidates[:4]
    selected_numbers.update(predictions['ชุดคาดการณ์ที่ 3 (เลขที่พักตัว มีโอกาสกลับมา)'])

    # --- ชุดคาดการณ์ที่ 4 (เลขกลุ่มกลางที่น่าสนใจ) ---
    # เลือกจาก eligible_overall ที่ยังไม่ถูกเลือก โดยเรียงตามความถี่รวม
    set4_candidates = [num for num in eligible_overall if num not in selected_numbers]
    predictions['ชุดคาดการณ์ที่ 4 (เลขกลุ่มกลางที่น่าจับตา)'] = set4_candidates[:4]
    selected_numbers.update(predictions['ชุดคาดการณ์ที่ 4 (เลขกลุ่มกลางที่น่าจับตา)'])

    # Ensure each set has 4 numbers, if not, fill from remaining eligible numbers
    for key in predictions:
        if len(predictions[key]) < 4:
            needed = 4 - len(predictions[key])
            fill_candidates = [num for num in eligible_overall if num not in selected_numbers]
            predictions[key].extend(fill_candidates[:needed])
            selected_numbers.update(fill_candidates[:needed])

    return predictions

# --- Main execution ---
if __name__ == "__main__":
    print("--- ระบบวิเคราะห์และทำนายล็อตเตอรี่ (Python) ---")
    print("--- ปรับปรุงระบบให้แข็งแกร่งขึ้นจากข้อมูลความถี่และวงรอบ ---")
    print("\n" + "="*60 + "\n")

    # 1. Parse data
    prize1_3digits_list, last2_digits_list = parse_lottery_data(raw_data)

    # 2. Analyze for 2-digit numbers
    print("### การวิเคราะห์สำหรับเลข 2 ตัวล่าง ###")
    two_digit_analysis = analyze_numbers(last2_digits_list, 2, num_recent_draws=10) # พิจารณา 10 งวดย้อนหลังสำหรับเลขร้อนล่าสุด
    print(f"จำนวนงวดทั้งหมด: {two_digit_analysis['totalDraws']}")
    print(f"จำนวนเลข 2 ตัวล่างที่เป็นไปได้: {two_digit_analysis['possibleNumbers']}")

    print("\n--- ผลการทำนายเลข 2 ตัวล่าง ---")
    print(f"  เลขที่ถูกตัดออก (เลขดับ & เลขเย็น - ความถี่ 0 หรือ 1 ครั้ง):")
    excluded_2d = sorted(list(set(two_digit_analysis['deadNumbers'] + two_digit_analysis['coldNumbers'])))
    print(f"    {', '.join(excluded_2d) if excluded_2d else 'ไม่มี'}")

    print(f"  เลขแนะนำ (เลขร้อน 10 อันดับแรกจากข้อมูลทั้งหมด):")
    print(f"    {', '.join([f'''{item['number']} ({item['frequency']} ครั้ง)''' for item in two_digit_analysis['hotNumbers']]) if two_digit_analysis['hotNumbers'] else 'ไม่มี'}")

    print(f"  เลขร้อนใน 10 งวดย้อนหลัง:")
    print(f"    {', '.join([f'''{item['number']} ({item['frequency']} ครั้ง)''' for item in two_digit_analysis['recentHotNumbers']]) if two_digit_analysis['recentHotNumbers'] else 'ไม่มี'}")

    print(f"  เลขที่เคยออกบ่อยแต่พักตัว (ความถี่รวมสูง, ความถี่ล่าสุดต่ำ):")
    print(f"    {', '.join([f'''{item['number']} (รวม {item['overall_frequency']} ครั้ง, ล่าสุด {item['recent_frequency']} ครั้ง)''' for item in two_digit_analysis['restingNumbers']]) if two_digit_analysis['restingNumbers'] else 'ไม่มี'}")

    print("\n  หมายเหตุ: ระบบนี้ใช้ข้อมูลประวัติจริงที่คุณให้มาเพื่อวิเคราะห์ความถี่และแนวโน้ม")

    # Predict 4 sets for 2-digit numbers
    print("\n--- 4 ชุดคาดการณ์สำหรับเลข 2 ตัวล่าง (ชุดละ 4 ตัว) ---")
    two_digit_predictions = predict_4_sets(two_digit_analysis, 2)
    for set_name, numbers in two_digit_predictions.items():
        print(f"  {set_name}: {', '.join(numbers) if numbers else 'ไม่มี'}")

    print("\n" + "="*60 + "\n")

    # 3. Analyze for 3-digit numbers
    print("### การวิเคราะห์สำหรับเลข 3 ตัวท้ายของรางวัลที่ 1 ###")
    three_digit_analysis = analyze_numbers(prize1_3digits_list, 3, num_recent_draws=10) # พิจารณา 10 งวดย้อนหลังสำหรับเลขร้อนล่าสุด
    print(f"จำนวนงวดทั้งหมด: {three_digit_analysis['totalDraws']}")
    print(f"จำนวนเลข 3 ตัวท้ายที่เป็นไปได้: {three_digit_analysis['possibleNumbers']}")

    print("\n--- ผลการทำนายเลข 3 ตัวท้าย ---")
    print(f"  เลขที่ถูกตัดออก (เลขดับ & เลขเย็น - ความถี่ 0 หรือ 1 ครั้ง):")
    excluded_3d = sorted(list(set(three_digit_analysis['deadNumbers'] + three_digit_analysis['coldNumbers'])))
    print(f"    {', '.join(excluded_3d) if excluded_3d else 'ไม่มี'}")

    print(f"  เลขแนะนำ (เลขร้อน 10 อันดับแรกจากข้อมูลทั้งหมด):")
    print(f"    {', '.join([f'''{item['number']} ({item['frequency']} ครั้ง)''' for item in three_digit_analysis['hotNumbers']]) if three_digit_analysis['hotNumbers'] else 'ไม่มี'}")

    print(f"  เลขร้อนใน 10 งวดย้อนหลัง:")
    print(f"    {', '.join([f'''{item['number']} ({item['frequency']} ครั้ง)''' for item in three_digit_analysis['recentHotNumbers']]) if three_digit_analysis['recentHotNumbers'] else 'ไม่มี'}")

    print(f"  เลขที่เคยออกบ่อยแต่พักตัว (ความถี่รวมสูง, ความถี่ล่าสุดต่ำ):")
    print(f"    {', '.join([f'''{item['number']} (รวม {item['overall_frequency']} ครั้ง, ล่าสุด {item['recent_frequency']} ครั้ง)''' for item in three_digit_analysis['restingNumbers']]) if three_digit_analysis['restingNumbers'] else 'ไม่มี'}")

    print("\n  หมายเหตุ: ระบบนี้ใช้ข้อมูลประวัติจริงที่คุณให้มาเพื่อวิเคราะห์ความถี่และแนวโน้ม")

    # Predict 4 sets for 3-digit numbers
    print("\n--- 4 ชุดคาดการณ์สำหรับเลข 3 ตัวท้าย (ชุดละ 4 ตัว) ---")
    three_digit_predictions = predict_4_sets(three_digit_analysis, 3)
    for set_name, numbers in three_digit_predictions.items():
        print(f"  {set_name}: {', '.join(numbers) if numbers else 'ไม่มี'}")

    print("\n" + "="*60 + "\n")
# Out:
# --- ระบบวิเคราะห์และทำนายล็อตเตอรี่ (Python) ---
# --- ปรับปรุงระบบให้แข็งแกร่งขึ้นจากข้อมูลความถี่และวงรอบ ---
#
# ============================================================
#
# ### การวิเคราะห์สำหรับเลข 2 ตัวล่าง ###
# จำนวนงวดทั้งหมด: 561
# จำนวนเลข 2 ตัวล่างที่เป็นไปได้: 100
#
# --- ผลการทำนายเลข 2 ตัวล่าง ---
#   เลขที่ถูกตัดออก (เลขดับ & เลขเย็น - ความถี่ 0 หรือ 1 ครั้ง):
#     74, 84
#   เลขแนะนำ (เลขร้อน 10 อันดับแรกจากข้อมูลทั้งหมด):
#     79 (12 ครั้ง), 85 (11 ครั้ง), 92 (11 ครั้ง), 69 (10 ครั้ง), 06 (9 ครั้ง), 14 (9 ครั้ง), 62 (9 ครั้ง), 98 (9 ครั้ง), 91 (8 ครั้ง), 87 (8 ครั้ง)
#   เลขร้อนใน 10 งวดย้อนหลัง:
#     06 (2 ครั้ง), 91 (1 ครั้ง), 20 (1 ครั้ง), 87 (1 ครั้ง), 85 (1 ครั้ง)
#   เลขที่เคยออกบ่อยแต่พักตัว (ความถี่รวมสูง, ความถี่ล่าสุดต่ำ):
#     79 (รวม 12 ครั้ง, ล่าสุด 0 ครั้ง), 85 (รวม 11 ครั้ง, ล่าสุด 1 ครั้ง), 92 (รวม 11 ครั้ง, ล่าสุด 0 ครั้ง), 69 (รวม 10 ครั้ง, ล่าสุด 0 ครั้ง), 14 (รวม 9 ครั้ง, ล่าสุด 0 ครั้ง), 62 (รวม 9 ครั้ง, ล่าสุด 0 ครั้ง), 98 (รวม 9 ครั้ง, ล่าสุด 0 ครั้ง), 91 (รวม 8 ครั้ง, ล่าสุด 1 ครั้ง), 87 (รวม 8 ครั้ง, ล่าสุด 1 ครั้ง), 50 (รวม 8 ครั้ง, ล่าสุด 1 ครั้ง), 64 (รวม 8 ครั้ง, ล่าสุด 0 ครั้ง), 53 (รวม 8 ครั้ง, ล่าสุด 0 ครั้ง), 57 (รวม 8 ครั้ง, ล่าสุด 0 ครั้ง), 95 (รวม 8 ครั้ง, ล่าสุด 0 ครั้ง), 05 (รวม 8 ครั้ง, ล่าสุด 0 ครั้ง), 25 (รวม 8 ครั้ง, ล่าสุด 0 ครั้ง), 20 (รวม 7 ครั้ง, ล่าสุด 1 ครั้ง), 51 (รวม 7 ครั้ง, ล่าสุด 0 ครั้ง), 59 (รวม 7 ครั้ง, ล่าสุด 0 ครั้ง)
#
#   หมายเหตุ: ระบบนี้ใช้ข้อมูลประวัติจริงที่คุณให้มาเพื่อวิเคราะห์ความถี่และแนวโน้ม
#
# --- 4 ชุดคาดการณ์สำหรับเลข 2 ตัวล่าง (ชุดละ 4 ตัว) ---
#   ชุดคาดการณ์ที่ 1 (เลขร้อนยอดนิยมจากทุกช่วง): 79, 85, 92, 69
#   ชุดคาดการณ์ที่ 2 (เลขร้อนในงวดล่าสุด): 06, 91, 20, 87
#   ชุดคาดการณ์ที่ 3 (เลขที่พักตัว มีโอกาสกลับมา): 14, 62, 98, 50
#   ชุดคาดการณ์ที่ 4 (เลขกลุ่มกลางที่น่าจับตา): 64, 53, 57, 95
#
# ============================================================
#
# ### การวิเคราะห์สำหรับเลข 3 ตัวท้ายของรางวัลที่ 1 ###
# จำนวนงวดทั้งหมด: 561
# จำนวนเลข 3 ตัวท้ายที่เป็นไปได้: 1000
#
# --- ผลการทำนายเลข 3 ตัวท้าย ---
#   เลขที่ถูกตัดออก (เลขดับ & เลขเย็น - ความถี่ 0 หรือ 1 ครั้ง):
#     000, 001, 002, 003, 004, 005, 006, 007, 008, 009, 010, 011, 013, 014, 015, 016, 017, 018, 019, 020, 021, 023, 024, 025, 026, 027, 028, 029, 030, 031, 032, 033, 034, 035, 036, 038, 039, 040, 041, 042, 043, 044, 045, 046, 047, 048, 049, 051, 053, 055, 056, 057, 058, 059, 060, 061, 063, 064, 065, 066, 067, 068, 069, 070, 071, 073, 074, 075, 076, 077, 078, 079, 080, 081, 082, 083, 084, 085, 086, 087, 088, 089, 090, 091, 092, 093, 094, 095, 096, 098, 099, 100, 101, 102, 103, 104, 105, 107, 108, 109, 110, 111, 112, 113, 114, 115, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 135, 136, 137, 138, 139, 140, 141, 142, 144, 145, 146, 147, 148, 150, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 197, 199, 200, 201, 202, 203, 204, 205, 206, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 259, 260, 262, 263, 264, 265, 266, 267, 268, 269, 271, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 325, 326, 328, 329, 330, 332, 333, 334, 335, 337, 338, 339, 340, 341, 342, 343, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 375, 376, 378, 379, 380, 381, 382, 383, 384, 385, 386, 389, 390, 392, 393, 394, 396, 397, 398, 399, 400, 401, 402, 405, 406, 407, 408, 409, 410, 412, 413, 414, 416, 418, 419, 420, 421, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 435, 436, 437, 439, 440, 441, 442, 443, 444, 445, 448, 449, 450, 451, 454, 455, 456, 457, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 468, 469, 470, 471, 472, 473, 474, 475, 476, 477, 478, 479, 480, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 520, 521, 522, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 534, 535, 536, 537, 538, 539, 540, 541, 542, 543, 544, 545, 546, 547, 548, 549, 550, 551, 552, 553, 555, 556, 557, 558, 559, 560, 561, 562, 563, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 576, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589, 591, 592, 593, 594, 595, 598, 599, 600, 601, 602, 604, 606, 607, 608, 609, 610, 611, 612, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622, 623, 624, 625, 626, 627, 629, 631, 632, 633, 634, 635, 636, 637, 638, 639, 640, 641, 642, 643, 644, 645, 646, 647, 648, 649, 651, 652, 653, 654, 655, 657, 658, 659, 660, 662, 663, 664, 665, 666, 667, 668, 669, 670, 671, 672, 673, 674, 675, 676, 677, 678, 679, 680, 681, 682, 683, 685, 686, 687, 688, 689, 690, 691, 692, 693, 694, 695, 696, 697, 698, 699, 700, 701, 702, 703, 705, 706, 707, 708, 709, 710, 711, 712, 713, 715, 716, 717, 718, 719, 720, 721, 722, 723, 724, 725, 726, 727, 728, 730, 731, 732, 733, 734, 735, 736, 737, 738, 739, 740, 741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 755, 757, 758, 759, 760, 762, 764, 765, 766, 768, 769, 770, 771, 772, 773, 774, 775, 776, 777, 778, 779, 780, 781, 782, 783, 784, 785, 786, 788, 789, 790, 791, 792, 793, 794, 795, 796, 797, 798, 799, 801, 802, 803, 805, 806, 807, 808, 809, 810, 811, 813, 814, 815, 817, 818, 819, 820, 821, 822, 823, 824, 826, 827, 828, 829, 830, 831, 832, 833, 834, 835, 836, 837, 838, 839, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 854, 855, 856, 857, 859, 860, 861, 862, 864, 865, 868, 869, 870, 871, 873, 874, 875, 876, 877, 878, 879, 880, 881, 882, 883, 884, 885, 886, 887, 888, 889, 890, 891, 892, 894, 8 ...
#   เลขแนะนำ (เลขร้อน 10 อันดับแรกจากข้อมูลทั้งหมด):
#     377 (4 ครั้ง), 422 (4 ครั้ง), 391 (4 ครั้ง), 684 (4 ครั้ง), 227 (3 ครั้ง), 867 (3 ครั้ง), 603 (3 ครั้ง), 417 (3 ครั้ง), 411 (3 ครั้ง), 196 (3 ครั้ง)
#   เลขร้อนใน 10 งวดย้อนหลัง:
#     246 (1 ครั้ง), 392 (1 ครั้ง), 352 (1 ครั้ง), 309 (1 ครั้ง), 388 (1 ครั้ง)
#   เลขที่เคยออกบ่อยแต่พักตัว (ความถี่รวมสูง, ความถี่ล่าสุดต่ำ):
#     377 (รวม 4 ครั้ง, ล่าสุด 1 ครั้ง), 422 (รวม 4 ครั้ง, ล่าสุด 0 ครั้ง), 391 (รวม 4 ครั้ง, ล่าสุด 0 ครั้ง), 684 (รวม 4 ครั้ง, ล่าสุด 0 ครั้ง), 227 (รวม 3 ครั้ง, ล่าสุด 1 ครั้ง), 867 (รวม 3 ครั้ง, ล่าสุด 0 ครั้ง), 603 (รวม 3 ครั้ง, ล่าสุด 0 ครั้ง), 417 (รวม 3 ครั้ง, ล่าสุด 0 ครั้ง), 411 (รวม 3 ครั้ง, ล่าสุด 0 ครั้ง), 196 (รวม 3 ครั้ง, ล่าสุด 0 ครั้ง), 372 (รวม 3 ครั้ง, ล่าสุด 0 ครั้ง), 564 (รวม 3 ครั้ง, ล่าสุด 0 ครั้ง), 327 (รวม 3 ครั้ง, ล่าสุด 0 ครั้ง), 630 (รวม 3 ครั้ง, ล่าสุด 0 ครั้ง), 438 (รวม 3 ครั้ง, ล่าสุด 0 ครั้ง), 825 (รวม 3 ครั้ง, ล่าสุด 0 ครั้ง)
#
#   หมายเหตุ: ระบบนี้ใช้ข้อมูลประวัติจริงที่คุณให้มาเพื่อวิเคราะห์ความถี่และแนวโน้ม
#
# --- 4 ชุดคาดการณ์สำหรับเลข 3 ตัวท้าย (ชุดละ 4 ตัว) ---
#   ชุดคาดการณ์ที่ 1 (เลขร้อนยอดนิยมจากทุกช่วง): 377, 422, 391, 684
#   ชุดคาดการณ์ที่ 2 (เลขร้อนในงวดล่าสุด): 246, 392, 352, 309
#   ชุดคาดการณ์ที่ 3 (เลขที่พักตัว มีโอกาสกลับมา): 227, 867, 603, 417
#   ชุดคาดการณ์ที่ 4 (เลขกลุ่มกลางที่น่าจับตา): 411, 196, 372, 564
#
# ============================================================
